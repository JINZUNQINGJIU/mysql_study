# %% [markdown]
# # task0 环境搭建

# %% [markdown]
# ## 1 环境安装

# %% [markdown]
# 根据Datawhale提供的教程安装SQL数据库系统，链接如下：
#
# https://hub.fastgit.org/datawhalechina/wonderful-sql/blob/main/ch00:%20%E7%8E%AF%E5%A2%83%E6%90%AD%E5%BB%BA.md

# %% [markdown]
# ## 2 链接SQL并查询

# %% [markdown]
# 按照教程操作，实现了数据库的连接和查询,截图如下：

# %% [markdown]
# ![image.png](attachment:image.png)
